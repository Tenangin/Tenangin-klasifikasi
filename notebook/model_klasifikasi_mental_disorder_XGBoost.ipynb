# %%
import pandas as pd 
import numpy as np  
import plotly.express as px 
import matplotlib.pyplot as plt
import seaborn as sb 
import plotly.subplots as sp
import plotly.graph_objs as go 
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report
from sklearn.ensemble import RandomForestClassifier

# %%
# Importing dataset
df=pd.read_csv('Dataset-Mental-Disorders.csv',index_col='Patient Number')
df.head(10)
# Out:
#                    Sadness    Euphoric   Exhausted Sleep dissorder Mood Swing  \
# Patient Number
# Patiant-01         Usually      Seldom   Sometimes       Sometimes        YES
# Patiant-02         Usually      Seldom     Usually       Sometimes         NO
# Patiant-03       Sometimes  Most-Often   Sometimes       Sometimes        YES
# Patiant-04         Usually      Seldom     Usually      Most-Often        YES
# Patiant-05         Usually     Usually   Sometimes       Sometimes         NO
# Patiant-06         Usually   Sometimes   Sometimes      Most-Often         NO
# Patiant-07          Seldom     Usually      Seldom       Sometimes        YES
# Patiant-08         Usually   Sometimes   Sometimes       Sometimes         NO
# Patiant-09      Most-Often      Seldom  Most-Often         Usually        YES
# Patiant-10         Usually      Seldom  Most-Often       Sometimes         NO
#
#                Suicidal thoughts Anorxia Authority Respect Try-Explanation  \
# Patient Number
# Patiant-01                  YES       NO                NO             YES
# Patiant-02                   YES      NO                NO              NO
# Patiant-03                    NO      NO                NO             YES
# Patiant-04                   YES     YES                NO             YES
# Patiant-05                    NO      NO                NO              NO
# Patiant-06                   YES     YES               YES              NO
# Patiant-07                   YES     YES                NO             YES
# Patiant-08                    NO      NO                NO             YES
# Patiant-09                   YES     YES                NO             YES
# Patiant-10                    NO      NO                NO             YES
#
#                Aggressive Response Ignore & Move-On Nervous Break-down  \
# Patient Number
# Patiant-01                      NO               NO                YES
# Patiant-02                      NO               NO                 NO
# Patiant-03                     YES               NO                YES
# Patiant-04                      NO               NO                 NO
# Patiant-05                      NO               NO                YES
# Patiant-06                      NO               NO                 NO
# Patiant-07                     YES               NO                YES
# Patiant-08                      NO               NO                 NO
# Patiant-09                     YES               NO                YES
# Patiant-10                      NO               NO                YES
#
#                Admit Mistakes Overthinking Sexual Activity Concentration  \
# Patient Number
# Patiant-01                YES          YES       3 From 10     3 From 10
# Patiant-02                 NO           NO       4 From 10     2 From 10
# Patiant-03                YES           NO       6 From 10     5 From 10
# Patiant-04                 NO           NO       3 From 10     2 From 10
# Patiant-05                YES          YES       5 From 10     5 From 10
# Patiant-06                YES           NO       3 From 10     5 From 10
# Patiant-07                YES          YES       7 From 10     2 From 10
# Patiant-08                 NO          YES       5 From 10     5 From 10
# Patiant-09                 NO           NO       8 From 10     2 From 10
# Patiant-10                YES          YES       3 From 10     4 From 10
#
#                 Optimisim Expert Diagnose
# Patient Number
# Patiant-01      4 From 10  Bipolar Type-2
# Patiant-02      5 From 10      Depression
# Patiant-03      7 From 10  Bipolar Type-1
# Patiant-04      2 From 10  Bipolar Type-2
# Patiant-05      6 From 10          Normal
# Patiant-06      5 From 10      Depression
# Patiant-07      9 From 10  Bipolar Type-1
# Patiant-08      5 From 10          Normal
# Patiant-09      3 From 10  Bipolar Type-2
# Patiant-10      2 From 10      Depression

# %%
#summery of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 120 entries, Patiant-01 to Patiant-120
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Sadness              120 non-null    object
#  1   Euphoric             120 non-null    object
#  2   Exhausted            120 non-null    object
#  3   Sleep dissorder      120 non-null    object
#  4   Mood Swing           120 non-null    object
#  5   Suicidal thoughts    120 non-null    object
#  6   Anorxia              120 non-null    object
#  7   Authority Respect    120 non-null    object
#  8   Try-Explanation      120 non-null    object
#  9   Aggressive Response  120 non-null    object
#  10  Ignore & Move-On     120 non-null    object
#  11  Nervous Break-down   120 non-null    object
#  12  Admit Mistakes       120 non-null    object
#  13  Overthinking         120 non-null    object
#  14  Sexual Activity      120 non-null    object
#  15  Concentration        120 non-null    object
#  16  Optimisim            120 non-null    object
#  17  Expert Diagnose      120 non-null    object
# dtypes: object(18)
# memory usage: 17.8+ KB

# %%
# df.drop(columns=['Sexual Activity'], inplace=True)

# %%
# unique values in each columns
for i in df.columns:
    print(f"{i}: {df[i].unique()}")
# Out:
# Sadness: ['Usually' 'Sometimes' 'Seldom' 'Most-Often']
# Euphoric: ['Seldom' 'Most-Often' 'Usually' 'Sometimes']
# Exhausted: ['Sometimes' 'Usually' 'Seldom' 'Most-Often']
# Sleep dissorder: ['Sometimes' 'Most-Often' 'Usually' 'Seldom']
# Mood Swing: ['YES' 'NO']
# Suicidal thoughts: ['YES ' 'YES' 'NO']
# Anorxia: ['NO' 'YES']
# Authority Respect: ['NO' 'YES']
# Try-Explanation: ['YES' 'NO']
# Aggressive Response: ['NO' 'YES']
# Ignore & Move-On: ['NO' 'YES']
# Nervous Break-down: ['YES' 'NO']
# Admit Mistakes: ['YES' 'NO']
# Overthinking: ['YES' 'NO']
# Sexual Activity: ['3 From 10' '4 From 10' '6 From 10' '5 From 10' '7 From 10' '8 From 10'
#  '9 From 10' '2 From 10' '1 From 10']
# Concentration: ['3 From 10' '2 From 10' '5 From 10' '4 From 10' '7 From 10' '6 From 10'
#  '1 From 10' '8 From 10']
# Optimisim: ['4 From 10' '5 From 10' '7 From 10' '2 From 10' '6 From 10' '9 From 10'
#  '3 From 10' '8 From 10' '1 From 10']
# Expert Diagnose: ['Bipolar Type-2' 'Depression' 'Bipolar Type-1' 'Normal']

# %%
# merging same values in 'Suicidal thoughts' column
df.loc[df[df['Suicidal thoughts']=='YES ']['Suicidal thoughts'].index[0],'Suicidal thoughts']='YES'

# %%
# We have catogorical features, so we need to encode them

from sklearn.preprocessing import LabelEncoder
encoders={} 
for i in df.columns[:-1]:
    encoders[i]=LabelEncoder() # define individual encoder for each column
    encoders[i].fit(df[i])
    df[i]=encoders[i].transform(df[i])

# %%
# Selecting best features in order to increase model's performance

from sklearn.feature_selection import mutual_info_classif
feature_selection=SelectKBest(score_func=mutual_info_classif)
feature_selection=feature_selection.fit(df[df.columns[:-1]],df[df.columns[-1]])

features_scores=pd.Series(feature_selection.scores_,df.columns[:-1])
features_scores.nlargest(18).plot(kind='barh',title="features' scores")
plt.show()

# %%
from sklearn.feature_selection import SelectKBest, mutual_info_classif
import pandas as pd
import matplotlib.pyplot as plt

# Misal df adalah DataFrame kamu
X = df[df.columns[:-1]]  # fitur
y = df[df.columns[-1]]   # label

# Feature selection
feature_selection = SelectKBest(score_func=mutual_info_classif)
feature_selection.fit(X, y)

# Buat Series skor
features_scores = pd.Series(feature_selection.scores_, index=X.columns)

# Tampilkan semua skor dengan print biasa
print("Skor masing-masing fitur:")
for feature, score in features_scores.items():
    print(f"{feature:25}: {score:.4f}")

# Visualisasi (opsional)
features_scores.nlargest(18).plot(kind='barh', title="Feature Importance Scores")
plt.show()
# Out:
# Skor masing-masing fitur:
# Sadness                  : 0.2777
# Euphoric                 : 0.1846
# Exhausted                : 0.1211
# Sleep dissorder          : 0.0599
# Mood Swing               : 0.5970
# Suicidal thoughts        : 0.1785
# Anorxia                  : 0.0418
# Authority Respect        : 0.1814
# Try-Explanation          : 0.0000
# Aggressive Response      : 0.0301
# Ignore & Move-On         : 0.0191
# Nervous Break-down       : 0.0490
# Admit Mistakes           : 0.0523
# Overthinking             : 0.0573
# Sexual Activity          : 0.3220
# Concentration            : 0.0829
# Optimisim                : 0.4078

# %%
# defining train and test set
# x_train,x_test,y_train,y_test=train_test_split(df[features_scores.nlargest(5).index],df[df.columns[-1]],test_size=0.3,random_state=2,shuffle=True)

# %%
X = df.drop(columns=[df.columns[-1]])  # semua fitur kecuali target
y = df[df.columns[-1]]                  # target

x_train, x_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.3,
    random_state=2,
    shuffle=True,
    stratify=y  # optional, kalau mau jaga proporsi kelas
)

# %%
from sklearn.preprocessing import LabelEncoder

# Encode label (y_train dan y_test jika perlu)
le = LabelEncoder()
y_train_encoded = le.fit_transform(y_train)

# %%
from sklearn.model_selection import GridSearchCV
from xgboost import XGBClassifier

param_grid = {
    'n_estimators': [100, 300],
    'max_depth': [3, 6],
    'learning_rate': [0.05, 0.1],
    'subsample': [0.8, 1]
}

model = XGBClassifier(use_label_encoder=False, eval_metric='logloss')
grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=3, n_jobs=-1, verbose=2, scoring='accuracy')
grid_search.fit(x_train, y_train_encoded)
# Out:
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# d:\DBS\Project Capstone\.venv\Lib\site-packages\xgboost\training.py:183: UserWarning: [18:20:58] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# GridSearchCV(cv=3,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False,
#                                      eval_metric='logloss', feature_types=None,
#                                      feature_weights=None, gamma=None,
#                                      grow_policy=None, importance_type=None,
#                                      interaction_constraint...
#                                      max_cat_to_onehot=None,
#                                      max_delta_step=None, max_depth=None,
#                                      max_leaves=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      multi_strategy=None, n_estimators=None,
#                                      n_jobs=None, num_parallel_tree=None, ...),
#              n_jobs=-1,
#              param_grid={'learning_rate': [0.05, 0.1], 'max_depth': [3, 6],
#                          'n_estimators': [100, 300], 'subsample': [0.8, 1]},
#              scoring='accuracy', verbose=2)

# %%
# best parameters for model
grid_search.best_params_
# Out:
# {'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 300, 'subsample': 1}

# %%
from sklearn.metrics import classification_report

# Encode y_test dengan encoder yang sama
y_test_encoded = le.transform(y_test)

# Prediksi
y_predict_encoded = grid_search.predict(x_test)

# Evaluasi
print(classification_report(y_test_encoded, y_predict_encoded, target_names=le.classes_))
# Out:
#                 precision    recall  f1-score   support
#
# Bipolar Type-1       0.71      0.56      0.62         9
# Bipolar Type-2       0.70      0.78      0.74         9
#     Depression       0.88      0.78      0.82         9
#         Normal       0.82      1.00      0.90         9
#
#       accuracy                           0.78        36
#      macro avg       0.78      0.78      0.77        36
#   weighted avg       0.78      0.78      0.77        36

# %%
df
# Out:
#                 Sadness  Euphoric  Exhausted  Sleep dissorder  Mood Swing  \
# Patient Number
# Patiant-01            3         1          2                2           1
# Patiant-02            3         1          3                2           0
# Patiant-03            2         0          2                2           1
# Patiant-04            3         1          3                0           1
# Patiant-05            3         3          2                2           0
# ...                 ...       ...        ...              ...         ...
# Patiant-116           0         1          3                2           0
# Patiant-117           2         2          2                1           1
# Patiant-118           3         2          3                2           1
# Patiant-119           3         2          1                1           0
# Patiant-120           2         3          1                3           0
#
#                 Suicidal thoughts  Anorxia  Authority Respect  \
# Patient Number
# Patiant-01                      1        0                  0
# Patiant-02                      1        0                  0
# Patiant-03                      0        0                  0
# Patiant-04                      1        1                  0
# Patiant-05                      0        0                  0
# ...                           ...      ...                ...
# Patiant-116                     1        0                  0
# Patiant-117                     0        0                  0
# Patiant-118                     0        1                  1
# Patiant-119                     1        1                  0
# Patiant-120                     0        0                  1
#
#                 Try-Explanation  Aggressive Response  Ignore & Move-On  \
# Patient Number
# Patiant-01                    1                    0                 0
# Patiant-02                    0                    0                 0
# Patiant-03                    1                    1                 0
# Patiant-04                    1                    0                 0
# Patiant-05                    0                    0                 0
# ...                         ...                  ...               ...
# Patiant-116                   1                    0                 1
# Patiant-117                   0                    1                 0
# Patiant-118                   0                    0                 0
# Patiant-119                   1                    1                 1
# Patiant-120                   1                    0                 1
#
#                 Nervous Break-down  Admit Mistakes  Overthinking  \
# Patient Number
# Patiant-01                       1               1             1
# Patiant-02                       0               0             0
# Patiant-03                       1               1             0
# Patiant-04                       0               0             0
# Patiant-05                       1               1             1
# ...                            ...             ...           ...
# Patiant-116                      0               0             1
# Patiant-117                      0               0             1
# Patiant-118                      1               0             1
# Patiant-119                      0               1             1
# Patiant-120                      1               0             0
#
#                 Sexual Activity  Concentration  Optimisim Expert Diagnose
# Patient Number
# Patiant-01                    2              2          3  Bipolar Type-2
# Patiant-02                    3              1          4      Depression
# Patiant-03                    5              4          6  Bipolar Type-1
# Patiant-04                    2              1          1  Bipolar Type-2
# Patiant-05                    4              4          5          Normal
# ...                         ...            ...        ...             ...
# Patiant-116                   1              4          2      Depression
# Patiant-117                   5              6          7  Bipolar Type-1
# Patiant-118                   0              4          2  Bipolar Type-2
# Patiant-119                   6              6          6      Depression
# Patiant-120                   6              2          7          Normal
#
# [120 rows x 18 columns]

# %% [markdown]
# # Save Model

# %%
import xgboost as xgb

# Simpan model ke file
model.save_model("model.json")
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[92], line 4
#       1 import xgboost as xgb
#       3 # Simpan model ke file
# ----> 4 model.save_model("model.json")
#
# File d:\DBS\Project Capstone\.venv\Lib\site-packages\xgboost\sklearn.py:1027, in XGBModel.save_model(self, fname)
#    1025 meta["_estimator_type"] = self._get_type()
#    1026 meta_str = json.dumps(meta)
# -> 1027 self.get_booster().set_attr(scikit_learn=meta_str)
#    1028 self.get_booster().save_model(fname)
#    1029 self.get_booster().set_attr(scikit_learn=None)
#
# File d:\DBS\Project Capstone\.venv\Lib\site-packages\xgboost\sklearn.py:922, in XGBModel.get_booster(self)
#     919 if not self.__sklearn_is_fitted__():
#     920     from sklearn.exceptions import NotFittedError
# --> 922     raise NotFittedError("need to call fit or load_model beforehand")
#     923 return self._Booster
#
# NotFittedError: need to call fit or load_model beforehand
